# %%
# DATA PREPROCESSING TEQNIQUES:
    # There are four main techniques for data preprocessing:
        # 1. Data Cleaning
        # 2. Data Integration
        # 3. Data Transformation
        # 4. Data Reduction

# 1. DATA CLEANING:
    # DATA CLEANING  TEQNIQUES:
        # 1. Handling Missing Data
        # 2. Smoothing Data
        # 3. Aggregation
        # 4. Discretization
        # 5. Attribute Transformation
        # 6. Normalization
        # 7. Standardization
        # 8. Concept Hierarchy Generation
        # 9. Attribute Subset Selection
        # 10. Attribute Creation
# 1.1 Handling Missing Data:
    # Missing data is a common problem in most data sources. 
    # Missing data can be handled in the following ways:
        # 1. Ignore the tuple
        # 2. Use a global constant to fill in the missing value
        # 3. Use the attribute mean to fill in the missing value
        # 4. Use the attribute mean for all samples belonging to the same class as the given tuple
        # 5. Predict the missing value using a learning algorithm
# 1.2 Smoothing Data:
    # Smoothing is a technique used to remove noise from data. 
    # Smoothing can be done using the following techniques:
        # 1. binning
        # 2. regression
        # 3. clustering
# 1.3 Aggregation:
    # Aggregation is a process where the values of two or more objects are combined into a single object. 
    # Aggregation can be done using the following techniques:
        # 1. Data Cube Aggregation
        # 2. Attribute Subset Selection
        # 3. Data Reduction
# 1.4 Discretization:
    # Discretization is a process of converting continuous data into discrete data. 
    # Discretization can be done using the following techniques:
        # 1. Equal Width Binning
        # 2. Equal Frequency Binning
        # 3. Clustering
        # 4. Decision Trees
# 1.5 Attribute Transformation:
    # Attribute transformation is a process of converting data from one form to another. 
    # Attribute transformation can be done using the following techniques:
        # 1. Normalization
        # 2. Standardization
        # 3. Concept Hierarchy Generation
# 1.6 Normalization:
    # Normalization is a technique used to scale the data of an attribute so that it falls in a smaller range, such as -1.0 to 1.0 or 0.0 to 1.0. 
    # Normalization can be done using the following formula:
        # Xnew = (X - Xmin) / (Xmax - Xmin)
# 1.7 Standardization:
    # Standardization is a technique used to transform the data in such a way that it has mean as 0 and variance as 1. 
    # Standardization can be done using the following formula:
        # Xnew = (X - mean) / standard deviation
# 1.8 Concept Hierarchy Generation:
    # Concept hierarchy generation is a process of defining a sequence of concepts that range from the most general concept to the most specific concept. 
    # Concept hierarchy generation can be done using the following techniques:
        # 1. Concept Hierarchy for Numeric Data
        # 2. Concept Hierarchy for Categorical Data

# 2. DATA INTEGRATION:
    # Data integration is a process of combining data from different sources into a single, unified view. 
    # Data integration can be done using the following techniques:
        # 1. Data Integration Using Data Warehousing
        # 2. Data Integration Using Virtual Integration
        # 3. Data Integration Using Common Format
        # 4. Data Integration Using Common Code
        # 5. Data Integration Using Common Domain
        # 6. Data Integration Using Common Schema
        # 7. Data Integration Using Common Vocabulary
        # 8. Data Integration Using Common Metadata
        # 9. Data Integration Using Common Key
        # 10. Data Integration Using Common Data Model
        # 11. Data Integration Using Common OLAP Operations
        # 12. Data Integration Using Common Query Language
        # 13. Data Integration Using Common Data Dictionary
        # 14. Data Integration Using Common Data Repository
        # 15. Data Integration Using Common Data Storage
        # 16. Data Integration Using Common Data Access
        # 17. Data Integration Using Common Data Exchange
        # 18. Data Integration Using Common Data Transformation
        # 19. Data Integration Using Common Data Cleaning
        # 20. Data Integration Using Common Data Reduction
        # 21. Data Integration Using Common Data Mining
        # 22. Data Integration Using Common Data Visualization
        # 23. Data Integration Using Common Data Analysis
        # 24. Data Integration Using Common Data Interpretation
        # 25. Data Integration Using Common Data Presentation
        # 26. Data Integration Using Common Data Reporting
        # 27. Data Integration Using Common Data Storage
        # 28. Data Integration Using Common Data Retrieval
        # 29. Data Integration Using Common Data Backup
        # 30. Data Integration Using Common Data Recovery
        # 31. Data Integration Using Common Data Security
        # 32. Data Integration Using Common Data Privacy
        # 33. Data Integration Using Common Data Confidentiality
        # 34. Data Integration Using Common Data Integrity
        # 35. Data Integration Using Common Data Availability
        # 36. Data Integration Using Common Data Scalability
        # 37. Data Integration Using Common Data Performance
        # 38. Data Integration Using Common Data Reliability
        # 39. Data Integration Using Common Data Durability
        # 40. Data Integration Using Common Data Consistency


# 3 DATA TRANSFORMATION:
    # Data transformation is a process of converting data from one format or structure into another format or structure. 
    # Data transformation can be done using the following techniques:
        # 1. Smoothing
        # 2. Aggregation
        # 3. Normalization
        # 4. Standardization
        # 5. Concept Hierarchy Generation
        # 6. Attribute Subset Selection
        # 7. Attribute Creation
        # 8. Discretization
        # 9. Data Reduction
